# %% [markdown]
# code to create a baseline pandemic flu simulation

# %%
import pandas as pd
import numpy as np
from scipy.spatial import distance_matrix
from random import randrange,randint,uniform,random,sample
from timeit import default_timer as timer
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
print("Hello Github 125")
threshold=6
cfr=0.1
quarantine=True
Num_days = 50
num_ppl = 5000
movement = 10
move_sdev = 5
size_min = 0
size_max = 500
p_zero = {'day':[], 'xpos':[], 'ypos':[]}
p_rand = {'day':[], 'xpos':[], 'ypos':[]}
# Out:
# Hello Github 125

# %% [markdown]
# Initializing a dataframe of 1000 'people' in a 2-dimensional space with various attributes.

# %%
def initialize():
    

    # various attributes of each person
    per_num = []
    x_pos = []
    y_pos = []
    infected = []
    time_infected = []
    recovered = []
    immune = []
    alive = []


    #for person number, x_pos and y_pos, we set these for each individaul

    for i in range(0,num_ppl):
        per_num.append(i)
        x_pos.append(np.random.randint(size_min,size_max))
        y_pos.append(np.random.randint(size_min,size_max))


    # for infected, time_infected, and alive, we set these for all people to start with default values
    infected = [0]*num_ppl
    time_infected = [np.NaN]*num_ppl
    alive = [1]*num_ppl
    recovered = [0]*num_ppl
    immune = [0]*num_ppl

    population = pd.DataFrame(list(zip(per_num, x_pos, y_pos, infected, time_infected, recovered, immune, alive)),
                              columns = ["per_num", "x_pos", "y_pos", "infected",  
                                         "time_infected", "recovered", "immune","alive"])
    rand=[randint(0, num_ppl) for p in range(0, 20)]
    print(rand)
    population.loc[rand, 'infected'] = 1
    population.loc[rand, 'time_infected'] = 0
#     print(population)
    
    
    return population

# %% [markdown]
# Now we infect patient 0 in our pandemic

# %% [markdown]
# Setting up parameters and logs for the simulation

# %%
def initiate_distance_matrix(population):
    
    # Setting parameters for movement of our simulated people 
    #the average person moves X units on the x axis and 10 units in the y axis. 
    #creating a log for the movement of patient zero (who we infect) & a random person (we'll pick person 25)

    p_zero = {'day':[], 'xpos':[], 'ypos':[]}

    p_rand = {'day':[], 'xpos':[], 'ypos':[]}

    infected_array = population.loc[(population['infected'] == 1), 'x_pos':'y_pos']
    pop_pos_array = population.loc[:, 'x_pos':'y_pos']

    #Initial distance matrix
    mtx0 = distance_matrix( pop_pos_array, infected_array)
    return mtx0

# %% [markdown]
# Running the simulation

# %%
# def movePeopleUsingDistribution(population):
#     for p in range(0,num_ppl):
#         #next, adjust movement (right now, everyone moves an average of 10 units each day)
#         #the first part creates a random variable from a normal dist. the second determines if it is positive or negative
#         x_move = np.random.normal(movement,move_sdev) * (-1 + 2*np.random.binomial(1,0.5))
#         y_move = np.random.normal(movement,move_sdev) * (-1 + 2*np.random.binomial(1,0.5))

#         if ((population.loc[p,'x_pos'] + x_move) < size_max) & ((population.loc[p,'x_pos'] + x_move) > size_min) :
#             population.loc[p,'x_pos'] = population.loc[p,'x_pos'] + x_move
#         else: 
#             population.loc[p,'x_pos'] = population.loc[p,'x_pos'] - x_move

#         if ((population.loc[p,'y_pos'] + y_move) < size_max) & ((population.loc[p,'y_pos'] + y_move) > size_min) :
#             population.loc[p,'y_pos'] = population.loc[p,'y_pos'] + y_move
#         else: 
#             population.loc[p,'y_pos'] = population.loc[p,'y_pos'] - y_move
#     return population

# def movePeopleRandomly(population):
#     population['x_pos'] = [random.uniform(size_min,size_max) for i in range(0,num_ppl)]
#     population['y_pos'] = [random.uniform(size_min,size_max) for i in range(0,num_ppl)]
#     return population


# start = timer()
# movePeopleUsingDistribution(population)
# end = timer()
# print("distribution: ",end-start)


# start1 = timer()
# movePeopleRandomly(population)
# end1 = timer()
# print("random positions: ",end1-start1)

def simulate(population,axs,mtx0):
    #creating a log for the simulation at each day
    results = {'day':[], 'new_infections':[], 'infected':[], 'recovered':[], 'immune':[], 'alive':[], 'dead':[]}

    mtx = mtx0

    for day in range(0, Num_days):
        t11=timer()

        new_infections = 0

        #loop through the population to determine status, and then change their position
        for p in range(0,num_ppl):
            #first determine if they were infected
            t1=timer()
            if population.loc[p,'infected'] == 0 and population.loc[p,'immune'] == 0:
                if(any(mtx[p]<=threshold)):
                    population.loc[p,'infected'] = 1
                    population.loc[p,'time_infected'] = day
                    new_infections += 1
    #                 print('person {p} infected on day {d}'.format(p = p, d = day))
            t2=timer()         
    #         print("time taken for new infections:",t2-t1)

            t3=timer()
            #next, for sick people, determine if they are better
            if (population.loc[p,'infected'] == 1 and population.loc[p,'alive'] == 1 and  (day - population.loc[p,'time_infected']) >14):
                population.loc[p,'infected'] = 0
                population.loc[p,'immune'] = 1
                population.loc[p,'recovered'] = 1
            t4=timer()         
    #         print("time taken for recoveries:",t4-t3)    



            t5=timer()
            #next, adjust movement (right now, everyone moves an average of 10 units each day)
            #the first part creates a random variable from a normal dist. the second determines if it is positive or negative
            x_move = np.random.normal(movement,move_sdev) * (-1 + 2*np.random.binomial(1,0.5))
            y_move = np.random.normal(movement,move_sdev) * (-1 + 2*np.random.binomial(1,0.5))
            if not(quarantine and population.loc[p,'infected'] == 1):
                if ((population.loc[p,'x_pos'] + x_move) < size_max) & ((population.loc[p,'x_pos'] + x_move) > size_min) :
                    population.loc[p,'x_pos'] = population.loc[p,'x_pos'] + x_move
                else: 
                    population.loc[p,'x_pos'] = population.loc[p,'x_pos'] - x_move

                if ((population.loc[p,'y_pos'] + y_move) < size_max) & ((population.loc[p,'y_pos'] + y_move) > size_min) :
                    population.loc[p,'y_pos'] = population.loc[p,'y_pos'] + y_move
                else: 
                    population.loc[p,'y_pos'] = population.loc[p,'y_pos'] - y_move

            t6=timer()
    #         print("new positions:",t6-t5)
            #now we need to make a new distance matrix
            infected_array_day = population.loc[(population['infected'] == 1), 'x_pos':'y_pos']
            pop_pos_array_day = population.loc[:, 'x_pos':'y_pos']
            

        list_of_infected=np.where((population["infected"] ==1) & (population["alive"]==1) & (population["time_infected"]>14))[0]
        num_of_infected=len(list_of_infected)
        new_deaths=round(num_of_infected*cfr)
#         print(type(list_of_infected[0:]))
        print("new deaths:"+new_deaths)
#         print(list_of_infected.tolist())
#         print(type(list_of_infected.tolist()))
        pop_death_indices=sample(list_of_infected.tolist(), new_deaths)
        population.loc[pop_death_indices,'alive']=0;
        
        
            
        t7=timer()
        #updated distance matrix
        mtx = distance_matrix( pop_pos_array_day, infected_array_day)
        t8 = timer()
    #         print("new distance matrix:",t8-t7)



        #update the log each day: 
        #path of patient zero
        p_zero['day'].append(day)
        p_zero['xpos'].append(population.loc[0,'x_pos'])
        p_zero['ypos'].append(population.loc[0,'y_pos'])

        #path of a random person (25)
        p_rand['day'].append(day)
        p_rand['xpos'].append(population.loc[25,'x_pos'])
        p_rand['ypos'].append(population.loc[25,'y_pos'])

        #overall results

        tot_infected = sum(population['infected'] == 1)
        tot_recovered = sum(population['recovered'] == 1)
        tot_immune = sum(population['immune'] == 1)
        tot_alive = sum(population['alive'] == 1)
        tot_dead=5000-tot_alive
        results['day'].append(day)
        results['new_infections'].append(new_infections)
        results['infected'].append(tot_infected)
        results['recovered'].append(tot_recovered)     
        results['immune'].append(tot_immune)  
        results['alive'].append(tot_alive)
        results['dead'].append(tot_dead)
        t12=timer()
    #     print("overall one day simulations:",t12-t11)

        print('Day {0} | {1} newly infected | {2} total infected | {3} have recovered | {4} died'.format(day, new_infections, tot_infected, tot_recovered , tot_dead))
    res=pd.DataFrame(results)
#     display(res)
    now = datetime.now()
    axs.plot(results["day"], results["new_infections"],label="new_infections")
    axs.plot(results["day"], results["recovered"], color='green',linewidth=1.0,label="recovered")
    axs.plot(results["day"], results["infected"],color='red', linewidth=1.0, linestyle='--',label="infected")
    axs.plot(results["day"], results["alive"],color='black', linewidth=1.0, linestyle='-.',label="alive")
    res.to_csv('simulation'+now.strftime("%m_%d_%Y, %H:%M:%S")+'.csv', encoding='utf-8')

fig, axs = plt.subplots(2)
fig.suptitle('With quarantine v/s without quarantine')

print("Simulation with quarantine in place")
pop1=initialize()
mtx0=initiate_distance_matrix(pop1)
simulate(pop1,axs[0],mtx0)


print("Simulation without quarantine in place")
quarantine=False
pop2=initialize()
mtx0=initiate_distance_matrix(pop2)
simulate(pop2,axs[1],mtx0)
plt.show()
# Out:
# Simulation with quarantine in place
# [4903, 182, 3374, 4894, 3546, 2204, 805, 1322, 2876, 3225, 3334, 3505, 2682, 714, 2564, 3435, 310, 123, 3130, 3887]
# Day 0 | 44 newly infected | 64 total infected | 0 have recovered | 0 died
# Day 1 | 77 newly infected | 141 total infected | 0 have recovered | 0 died
# Day 2 | 105 newly infected | 246 total infected | 0 have recovered | 0 died
# Day 3 | 92 newly infected | 338 total infected | 0 have recovered | 0 died
# Day 4 | 114 newly infected | 452 total infected | 0 have recovered | 0 died
# Day 5 | 122 newly infected | 574 total infected | 0 have recovered | 0 died
# Day 6 | 126 newly infected | 700 total infected | 0 have recovered | 0 died
# Day 7 | 118 newly infected | 818 total infected | 0 have recovered | 0 died
# Day 8 | 122 newly infected | 940 total infected | 0 have recovered | 0 died
# Day 9 | 117 newly infected | 1057 total infected | 0 have recovered | 0 died
# Day 10 | 116 newly infected | 1173 total infected | 0 have recovered | 0 died
# Day 11 | 111 newly infected | 1284 total infected | 0 have recovered | 0 died
# Day 12 | 113 newly infected | 1397 total infected | 0 have recovered | 0 died
# Day 13 | 101 newly infected | 1498 total infected | 0 have recovered | 0 died
# Day 14 | 106 newly infected | 1604 total infected | 0 have recovered | 0 died
# Day 15 | 115 newly infected | 1655 total infected | 64 have recovered | 12 died
# Day 16 | 103 newly infected | 1681 total infected | 141 have recovered | 33 died
# Day 17 | 91 newly infected | 1667 total infected | 246 have recovered | 61 died
# Day 18 | 96 newly infected | 1671 total infected | 338 have recovered | 95 died
# Day 19 | 97 newly infected | 1654 total infected | 452 have recovered | 136 died
# Day 20 | 78 newly infected | 1610 total infected | 574 have recovered | 180 died
# Day 21 | 72 newly infected | 1556 total infected | 700 have recovered | 227 died
# Day 22 | 104 newly infected | 1542 total infected | 818 have recovered | 280 died
# Day 23 | 76 newly infected | 1496 total infected | 940 have recovered | 335 died
# Day 24 | 66 newly infected | 1445 total infected | 1057 have recovered | 391 died
# Day 25 | 94 newly infected | 1423 total infected | 1173 have recovered | 451 died
# Day 26 | 67 newly infected | 1379 total infected | 1284 have recovered | 512 died
# Day 27 | 67 newly infected | 1333 total infected | 1397 have recovered | 573 died
# Day 28 | 72 newly infected | 1304 total infected | 1498 have recovered | 635 died
# Day 29 | 81 newly infected | 1279 total infected | 1604 have recovered | 699 died
# Day 30 | 78 newly infected | 1330 total infected | 1631 have recovered | 762 died
# Day 31 | 63 newly infected | 1373 total infected | 1651 have recovered | 823 died
# Day 32 | 74 newly infected | 1422 total infected | 1676 have recovered | 883 died
# Day 33 | 67 newly infected | 1478 total infected | 1687 have recovered | 943 died
# Day 34 | 60 newly infected | 1518 total infected | 1707 have recovered | 1001 died
# Day 35 | 65 newly infected | 1570 total infected | 1720 have recovered | 1058 died
# Day 36 | 56 newly infected | 1610 total infected | 1736 have recovered | 1113 died
# Day 37 | 54 newly infected | 1641 total infected | 1759 have recovered | 1166 died
# Day 38 | 58 newly infected | 1680 total infected | 1778 have recovered | 1217 died
# Day 39 | 55 newly infected | 1728 total infected | 1785 have recovered | 1268 died
# Day 40 | 47 newly infected | 1757 total infected | 1803 have recovered | 1317 died
# Day 41 | 56 newly infected | 1799 total infected | 1817 have recovered | 1365 died
# Day 42 | 59 newly infected | 1843 total infected | 1832 have recovered | 1413 died
# Day 43 | 55 newly infected | 1874 total infected | 1856 have recovered | 1459 died
# Day 44 | 55 newly infected | 1909 total infected | 1876 have recovered | 1504 died
# Day 45 | 53 newly infected | 1949 total infected | 1889 have recovered | 1548 died
# Day 46 | 49 newly infected | 1979 total infected | 1908 have recovered | 1591 died
# Day 47 | 54 newly infected | 2018 total infected | 1923 have recovered | 1634 died
# Day 48 | 40 newly infected | 2049 total infected | 1932 have recovered | 1676 died
# Day 49 | 43 newly infected | 2080 total infected | 1944 have recovered | 1716 died
# Simulation without quarantine in place
# [4802, 3156, 1803, 833, 2753, 659, 1851, 3577, 2893, 1849, 2700, 4655, 4811, 2392, 4053, 192, 1963, 1307, 2594, 806]
# Day 0 | 33 newly infected | 53 total infected | 0 have recovered | 0 died
# Day 1 | 97 newly infected | 150 total infected | 0 have recovered | 0 died
# Day 2 | 228 newly infected | 378 total infected | 0 have recovered | 0 died
# Day 3 | 492 newly infected | 870 total infected | 0 have recovered | 0 died
# Day 4 | 686 newly infected | 1556 total infected | 0 have recovered | 0 died
# Day 5 | 827 newly infected | 2383 total infected | 0 have recovered | 0 died
# Day 6 | 746 newly infected | 3129 total infected | 0 have recovered | 0 died
# Day 7 | 660 newly infected | 3789 total infected | 0 have recovered | 0 died
# Day 8 | 498 newly infected | 4287 total infected | 0 have recovered | 0 died
# Day 9 | 308 newly infected | 4595 total infected | 0 have recovered | 0 died
# Day 10 | 216 newly infected | 4811 total infected | 0 have recovered | 0 died
# Day 11 | 118 newly infected | 4929 total infected | 0 have recovered | 0 died
# Day 12 | 53 newly infected | 4982 total infected | 0 have recovered | 0 died
# Day 13 | 17 newly infected | 4999 total infected | 0 have recovered | 0 died
# Day 14 | 1 newly infected | 5000 total infected | 0 have recovered | 0 died
# Day 15 | 0 newly infected | 4947 total infected | 53 have recovered | 0 died
# Day 16 | 0 newly infected | 4850 total infected | 150 have recovered | 0 died
# Day 17 | 0 newly infected | 4622 total infected | 378 have recovered | 0 died
# Day 18 | 0 newly infected | 4130 total infected | 870 have recovered | 0 died
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-faab27e749e5> in <module>
#     163 pop2=initialize()
#     164 mtx0=initiate_distance_matrix(pop2)
# --> 165 simulate(pop2,axs[1],mtx0)
#     166 plt.show()
#
# <ipython-input-4-faab27e749e5> in simulate(population, axs, mtx0)
#     106         t7=timer()
#     107         #updated distance matrix
# --> 108         mtx = distance_matrix( pop_pos_array_day, infected_array_day)
#     109         t8 = timer()
#     110     #         print("new distance matrix:",t8-t7)
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/spatial/kdtree.py in distance_matrix(x, y, p, threshold)
#     996         else:
#     997             for j in range(n):
# --> 998                 result[:,j] = minkowski_distance(x,y[j],p)
#     999         return result
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/spatial/kdtree.py in minkowski_distance(x, y, p)
#      78         return minkowski_distance_p(x, y, p)
#      79     else:
# ---> 80         return minkowski_distance_p(x, y, p)**(1./p)
#      81
#      82
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/spatial/kdtree.py in minkowski_distance_p(x, y, p)
#      42
#      43     # Make sure x and y are NumPy arrays of correct datatype.
# ---> 44     x = x.astype(common_datatype)
#      45     y = y.astype(common_datatype)
#      46
#
# KeyboardInterrupt:

# %%
print(np.random.normal(movement,move_sdev)*(-1 + 2*np.random.binomial(1,0.5)))
