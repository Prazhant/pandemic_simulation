# %% [markdown]
# code to create a baseline pandemic flu simulation

# %%
import pandas as pd
import numpy as np
from scipy.spatial import distance_matrix
from random import randrange,randint,uniform
from timeit import default_timer as timer
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import numpy as np
print("Hello Github 125")
threshold=6
cfr=0.1
quarantine=True
# Out:
# Hello Github 125

# %% [markdown]
# Initializing a dataframe of 1000 'people' in a 2-dimensional space with various attributes.

# %%
num_ppl = 1000

# various attributes of each person
per_num = []
x_pos = []
y_pos = []
infected = []
time_infected = []
recovered = []
immune = []
alive = []


#for person number, x_pos and y_pos, we set these for each individaul
size_min = 0
size_max = 500
for i in range(0,num_ppl):
    per_num.append(i)
    x_pos.append(np.random.randint(size_min,size_max))
    y_pos.append(np.random.randint(size_min,size_max))

    
# for infected, time_infected, and alive, we set these for all people to start with default values
infected = [0]*num_ppl
time_infected = [np.NaN]*num_ppl
alive = [1]*num_ppl
recovered = [0]*num_ppl
immune = [0]*num_ppl

population = pd.DataFrame(list(zip(per_num, x_pos, y_pos, infected, time_infected, recovered, immune, alive)),
                          columns = ["per_num", "x_pos", "y_pos", "infected",  
                                     "time_infected", "recovered", "immune","alive"])

print(population)
# Out:
#      per_num  x_pos  y_pos  infected  time_infected  recovered  immune  alive
# 0          0    315    456         0            NaN          0       0      1
# 1          1    105     73         0            NaN          0       0      1
# 2          2    140    410         0            NaN          0       0      1
# 3          3     91    270         0            NaN          0       0      1
# 4          4    346    171         0            NaN          0       0      1
# ..       ...    ...    ...       ...            ...        ...     ...    ...
# 995      995    245    326         0            NaN          0       0      1
# 996      996    366    496         0            NaN          0       0      1
# 997      997    139    473         0            NaN          0       0      1
# 998      998    186    189         0            NaN          0       0      1
# 999      999     86    492         0            NaN          0       0      1
#
# [1000 rows x 8 columns]

# %% [markdown]
# Now we infect patient 0 in our pandemic

# %%
rand=[randint(0, 1000) for p in range(0, 20)]
print(rand)
population.loc[rand, 'infected'] = 1
population.loc[rand, 'time_infected'] = 0
print(population)
# Out:
# [259, 427, 134, 610, 839, 27, 82, 873, 51, 493, 62, 230, 917, 194, 695, 554, 291, 412, 832, 124]
#      per_num  x_pos  y_pos  infected  time_infected  recovered  immune  alive
# 0          0    315    456         0            NaN          0       0      1
# 1          1    105     73         0            NaN          0       0      1
# 2          2    140    410         0            NaN          0       0      1
# 3          3     91    270         0            NaN          0       0      1
# 4          4    346    171         0            NaN          0       0      1
# ..       ...    ...    ...       ...            ...        ...     ...    ...
# 995      995    245    326         0            NaN          0       0      1
# 996      996    366    496         0            NaN          0       0      1
# 997      997    139    473         0            NaN          0       0      1
# 998      998    186    189         0            NaN          0       0      1
# 999      999     86    492         0            NaN          0       0      1
#
# [1000 rows x 8 columns]

# %% [markdown]
# Setting up parameters and logs for the simulation

# %%
# Setting parameters for movement of our simulated people 
#the average person moves X units on the x axis and 10 units in the y axis. 
movement = 10
move_sdev = 5

Num_days = 50

#creating a log for the movement of patient zero (who we infect) & a random person (we'll pick person 25)

p_zero = {'day':[], 'xpos':[], 'ypos':[]}

p_rand = {'day':[], 'xpos':[], 'ypos':[]}

#creating a log for the simulation at each day

results = {'day':[], 'new_infections':[], 'infected':[], 'recovered':[], 'immune':[], 'alive':[]}


infected_array = population.loc[(population['infected'] == 1), 'x_pos':'y_pos']
pop_pos_array = population.loc[:, 'x_pos':'y_pos']

#Initial distance matrix
mtx0 = distance_matrix( pop_pos_array, infected_array)
# display(mtx0)
# print(mtx0.shape)

# s2=timer()
# result = [np.where((row < threshold)) for row in mtx0]
# idx=0
# ctr3=0
# for proximity in result:
#     if(len(proximity[0])>0):
#         print("indices: ",idx)
#         ctr3+=1

#     idx+=1
# e2=timer()
# print(ctr3)
# print("time taken:",e2-s2)

# s3=timer()

ctr=0
for p in range(0,num_ppl):
    for infected_dist in mtx0[p]:
        if infected_dist <= 6:
            print(p)
            ctr+=1
e3=timer()
print("number of ppl in the proximity:",ctr)
print("time taken:",e3-s3)
# Out:
# 9
# 17
# 27
# 51
# 62
# 79
# 82
# 124
# 132
# 134
# 156
# 194
# 212
# 230
# 259
# 291
# 412
# 427
# 439
# 493
# 554
# 610
# 695
# 708
# 832
# 839
# 854
# 873
# 909
# 917
# 948
# 955
# number of ppl in the proximity: 32
# time taken: 47547.112659599996

# %% [markdown]
# Running the simulation

# %%
def movePeopleUsingDistribution(population):
    for p in range(0,num_ppl):
        #next, adjust movement (right now, everyone moves an average of 10 units each day)
        #the first part creates a random variable from a normal dist. the second determines if it is positive or negative
        x_move = np.random.normal(movement,move_sdev) * (-1 + 2*np.random.binomial(1,0.5))
        y_move = np.random.normal(movement,move_sdev) * (-1 + 2*np.random.binomial(1,0.5))

        if ((population.loc[p,'x_pos'] + x_move) < size_max) & ((population.loc[p,'x_pos'] + x_move) > size_min) :
            population.loc[p,'x_pos'] = population.loc[p,'x_pos'] + x_move
        else: 
            population.loc[p,'x_pos'] = population.loc[p,'x_pos'] - x_move

        if ((population.loc[p,'y_pos'] + y_move) < size_max) & ((population.loc[p,'y_pos'] + y_move) > size_min) :
            population.loc[p,'y_pos'] = population.loc[p,'y_pos'] + y_move
        else: 
            population.loc[p,'y_pos'] = population.loc[p,'y_pos'] - y_move
    return population

def movePeopleRandomly(population):
    population['x_pos'] = [random.uniform(size_min,size_max) for i in range(0,num_ppl)]
    population['y_pos'] = [random.uniform(size_min,size_max) for i in range(0,num_ppl)]
    return population


# start = timer()
# movePeopleUsingDistribution(population)
# end = timer()
# print("distribution: ",end-start)


# start1 = timer()
# movePeopleRandomly(population)
# end1 = timer()
# print("random positions: ",end1-start1)

def simulate():
    mtx = mtx0

    for day in range(0, Num_days):
        t11=timer()

        new_infections = 0

        #loop through the population to determine status, and then change their position
        for p in range(0,num_ppl):
            #first determine if they were infected
            t1=timer()
            if population.loc[p,'infected'] == 0 and population.loc[p,'immune'] == 0:
                if(any(mtx[p]<=threshold)):
                    population.loc[p,'infected'] = 1
                    population.loc[p,'time_infected'] = day
                    new_infections += 1
    #                 print('person {p} infected on day {d}'.format(p = p, d = day))
            t2=timer()         
    #         print("time taken for new infections:",t2-t1)

            t3=timer()
            #next, for sick people, determine if they are better
            if (population.loc[p,'infected'] == 1 and population.loc[p,'alive'] == 1 and  (day - population.loc[p,'time_infected']) >14):
                population.loc[p,'infected'] = 0
                population.loc[p,'immune'] = 1
                population.loc[p,'recovered'] = 1
            t4=timer()         
    #         print("time taken for recoveries:",t4-t3)    



            t5=timer()
            #next, adjust movement (right now, everyone moves an average of 10 units each day)
            #the first part creates a random variable from a normal dist. the second determines if it is positive or negative
            x_move = np.random.normal(movement,move_sdev) * (-1 + 2*np.random.binomial(1,0.5))
            y_move = np.random.normal(movement,move_sdev) * (-1 + 2*np.random.binomial(1,0.5))
            if not(quarantine and population.loc[p,'infected'] == 1):
                if ((population.loc[p,'x_pos'] + x_move) < size_max) & ((population.loc[p,'x_pos'] + x_move) > size_min) :
                    population.loc[p,'x_pos'] = population.loc[p,'x_pos'] + x_move
                else: 
                    population.loc[p,'x_pos'] = population.loc[p,'x_pos'] - x_move

                if ((population.loc[p,'y_pos'] + y_move) < size_max) & ((population.loc[p,'y_pos'] + y_move) > size_min) :
                    population.loc[p,'y_pos'] = population.loc[p,'y_pos'] + y_move
                else: 
                    population.loc[p,'y_pos'] = population.loc[p,'y_pos'] - y_move

            t6=timer()
    #         print("new positions:",t6-t5)
            #now we need to make a new distance matrix
            infected_array_day = population.loc[(population['infected'] == 1), 'x_pos':'y_pos']
            pop_pos_array_day = population.loc[:, 'x_pos':'y_pos']

        list_of_infected=np.where((population["infected"] ==1) & (population["alive"]==1) & (population["time_infected"]>14))[0]
        num_of_infected=len(list_of_infected)
        new_deaths=round(num_of_infected)
#         print(type(list_of_infected[0:]))
#         print(new_deaths)
#         print(list_of_infected.tolist())
#         print(type(list_of_infected.tolist()))
        pop_death_indices=random.sample(list_of_infected.tolist(), new_deaths)
        population.loc[pop_death_indices,'alive']=0;
        
        
            
        t7=timer()
        #updated distance matrix
        mtx = distance_matrix( pop_pos_array_day, infected_array_day)
        t8 = timer()
    #         print("new distance matrix:",t8-t7)



        #update the log each day: 
        #path of patient zero
        p_zero['day'].append(day)
        p_zero['xpos'].append(population.loc[0,'x_pos'])
        p_zero['ypos'].append(population.loc[0,'y_pos'])

        #path of a random person (25)
        p_rand['day'].append(day)
        p_rand['xpos'].append(population.loc[25,'x_pos'])
        p_rand['ypos'].append(population.loc[25,'y_pos'])

        #overall results

        tot_infected = sum(population['infected'] == 1)
        tot_recovered = sum(population['recovered'] == 1)
        tot_immune = sum(population['immune'] == 1)
        tot_alive = sum(population['alive'] == 1)
        results['day'].append(day)
        results['new_infections'].append(new_infections)
        results['infected'].append(tot_infected)
        results['recovered'].append(tot_recovered)     
        results['immune'].append(tot_immune)  
        results['alive'].append(tot_alive)
        t12=timer()
    #     print("overall one day simulations:",t12-t11)

        print('Day {0} | {1} newly infected | {2} total infected | {3} have recovered'.format(day, new_infections, tot_infected, tot_recovered))
        
simulate()
res=pd.DataFrame(results)
display(res)
fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(results["day"], results["new_infections"],label="new_infections")
axs[0].plot(results["day"], results["recovered"], color='green',linewidth=1.0,label="recovered")
axs[0].plot(results["day"], results["infected"],color='red', linewidth=1.0, linestyle='--',label="infected")
axs[0].plot(results["day"], results["alive"],color='black', linewidth=1.0, linestyle='-.',label="alive")

plt.show()

plt.show()
quarantine=False
simulate()
res=pd.DataFrame(results)
display(res)
axs[1].plot(results["day"], results["new_infections"],label="new_infections")
axs[1].plot(results["day"], results["recovered"], color='green',linewidth=1.0,label="recovered")
axs[1].plot(results["day"], results["infected"],color='red', linewidth=1.0, linestyle='--',label="infected")
axs[1].plot(results["day"], results["alive"],color='black', linewidth=1.0, linestyle='-.',label="alive")
plt.show()
# Out:
# Day 0 | 0 newly infected | 354 total infected | 205 have recovered
# Day 1 | 10 newly infected | 364 total infected | 205 have recovered
# Day 2 | 3 newly infected | 367 total infected | 205 have recovered
# Day 3 | 7 newly infected | 374 total infected | 205 have recovered
# Day 4 | 5 newly infected | 379 total infected | 205 have recovered
# Day 5 | 8 newly infected | 387 total infected | 205 have recovered
# Day 6 | 8 newly infected | 395 total infected | 205 have recovered
# Day 7 | 6 newly infected | 401 total infected | 205 have recovered
# Day 8 | 15 newly infected | 416 total infected | 205 have recovered
# Day 9 | 4 newly infected | 420 total infected | 205 have recovered
# Day 10 | 10 newly infected | 430 total infected | 205 have recovered
# Day 11 | 3 newly infected | 433 total infected | 205 have recovered
# Day 12 | 1 newly infected | 434 total infected | 205 have recovered
# Day 13 | 2 newly infected | 436 total infected | 205 have recovered
# Day 14 | 5 newly infected | 441 total infected | 205 have recovered
# Day 15 | 4 newly infected | 445 total infected | 205 have recovered
# Day 16 | 7 newly infected | 442 total infected | 215 have recovered
# Day 17 | 3 newly infected | 442 total infected | 218 have recovered
# Day 18 | 5 newly infected | 440 total infected | 225 have recovered
# Day 19 | 7 newly infected | 442 total infected | 230 have recovered
# Day 20 | 5 newly infected | 439 total infected | 238 have recovered
# Day 21 | 4 newly infected | 435 total infected | 246 have recovered
# Day 22 | 1 newly infected | 430 total infected | 252 have recovered
# Day 23 | 6 newly infected | 421 total infected | 267 have recovered
# Day 24 | 3 newly infected | 420 total infected | 271 have recovered
# Day 25 | 2 newly infected | 412 total infected | 281 have recovered
# Day 26 | 3 newly infected | 412 total infected | 284 have recovered
# Day 27 | 2 newly infected | 413 total infected | 285 have recovered
# Day 28 | 7 newly infected | 418 total infected | 287 have recovered
# Day 29 | 3 newly infected | 416 total infected | 292 have recovered
# Day 30 | 5 newly infected | 421 total infected | 292 have recovered
# Day 31 | 7 newly infected | 428 total infected | 292 have recovered
# Day 32 | 4 newly infected | 432 total infected | 292 have recovered
# Day 33 | 6 newly infected | 438 total infected | 292 have recovered
# Day 34 | 3 newly infected | 441 total infected | 292 have recovered
# Day 35 | 4 newly infected | 445 total infected | 292 have recovered
# Day 36 | 4 newly infected | 449 total infected | 292 have recovered
# Day 37 | 3 newly infected | 452 total infected | 292 have recovered
# Day 38 | 2 newly infected | 454 total infected | 292 have recovered
# Day 39 | 5 newly infected | 459 total infected | 292 have recovered
# Day 40 | 3 newly infected | 462 total infected | 292 have recovered
# Day 41 | 2 newly infected | 464 total infected | 292 have recovered
# Day 42 | 6 newly infected | 470 total infected | 292 have recovered
# Day 43 | 3 newly infected | 473 total infected | 292 have recovered
# Day 44 | 3 newly infected | 476 total infected | 292 have recovered
# Day 45 | 1 newly infected | 477 total infected | 292 have recovered
# Day 46 | 2 newly infected | 479 total infected | 292 have recovered
# Day 47 | 2 newly infected | 481 total infected | 292 have recovered
# Day 48 | 2 newly infected | 483 total infected | 292 have recovered
# Day 49 | 2 newly infected | 485 total infected | 292 have recovered
#     day  new_infections  infected  recovered  immune  alive
# 0     0              12        32          0       0   1000
# 1     1              11        43          0       0   1000
# 2     2               8        51          0       0   1000
# 3     3              10        61          0       0   1000
# 4     4              15        76          0       0   1000
# ..  ...             ...       ...        ...     ...    ...
# 95   45               1       477        292     292    523
# 96   46               2       479        292     292    521
# 97   47               2       481        292     292    519
# 98   48               2       483        292     292    517
# 99   49               2       485        292     292    515
#
# [100 rows x 6 columns]
# Day 0 | 0 newly infected | 485 total infected | 292 have recovered
# Day 1 | 13 newly infected | 498 total infected | 292 have recovered
# Day 2 | 8 newly infected | 506 total infected | 292 have recovered
# Day 3 | 2 newly infected | 508 total infected | 292 have recovered
# Day 4 | 9 newly infected | 517 total infected | 292 have recovered
# Day 5 | 13 newly infected | 530 total infected | 292 have recovered
# Day 6 | 8 newly infected | 538 total infected | 292 have recovered
# Day 7 | 13 newly infected | 551 total infected | 292 have recovered
# Day 8 | 7 newly infected | 558 total infected | 292 have recovered
# Day 9 | 7 newly infected | 565 total infected | 292 have recovered
# Day 10 | 9 newly infected | 574 total infected | 292 have recovered
# Day 11 | 10 newly infected | 584 total infected | 292 have recovered
# Day 12 | 7 newly infected | 591 total infected | 292 have recovered
# Day 13 | 6 newly infected | 597 total infected | 292 have recovered
# Day 14 | 12 newly infected | 609 total infected | 292 have recovered
# Day 15 | 13 newly infected | 622 total infected | 292 have recovered
# Day 16 | 8 newly infected | 617 total infected | 305 have recovered
# Day 17 | 9 newly infected | 618 total infected | 313 have recovered
# Day 18 | 5 newly infected | 621 total infected | 315 have recovered
# Day 19 | 6 newly infected | 618 total infected | 324 have recovered
# Day 20 | 4 newly infected | 609 total infected | 337 have recovered
# Day 21 | 11 newly infected | 612 total infected | 345 have recovered
# Day 22 | 4 newly infected | 603 total infected | 358 have recovered
# Day 23 | 6 newly infected | 602 total infected | 365 have recovered
# Day 24 | 5 newly infected | 600 total infected | 372 have recovered
# Day 25 | 3 newly infected | 594 total infected | 381 have recovered
# Day 26 | 5 newly infected | 589 total infected | 391 have recovered
# Day 27 | 3 newly infected | 585 total infected | 398 have recovered
# Day 28 | 1 newly infected | 580 total infected | 404 have recovered
# Day 29 | 2 newly infected | 570 total infected | 416 have recovered
# Day 30 | 0 newly infected | 570 total infected | 416 have recovered
# Day 31 | 0 newly infected | 570 total infected | 416 have recovered
# Day 32 | 0 newly infected | 570 total infected | 416 have recovered
# Day 33 | 3 newly infected | 573 total infected | 416 have recovered
# Day 34 | 2 newly infected | 575 total infected | 416 have recovered
# Day 35 | 2 newly infected | 577 total infected | 416 have recovered
# Day 36 | 0 newly infected | 577 total infected | 416 have recovered
# Day 37 | 1 newly infected | 578 total infected | 416 have recovered
# Day 38 | 0 newly infected | 578 total infected | 416 have recovered
# Day 39 | 1 newly infected | 579 total infected | 416 have recovered
# Day 40 | 2 newly infected | 581 total infected | 416 have recovered
# Day 41 | 1 newly infected | 582 total infected | 416 have recovered
# Day 42 | 1 newly infected | 583 total infected | 416 have recovered
# Day 43 | 0 newly infected | 583 total infected | 416 have recovered
# Day 44 | 0 newly infected | 583 total infected | 416 have recovered
# Day 45 | 0 newly infected | 583 total infected | 416 have recovered
# Day 46 | 0 newly infected | 583 total infected | 416 have recovered
# Day 47 | 0 newly infected | 583 total infected | 416 have recovered
# Day 48 | 0 newly infected | 583 total infected | 416 have recovered
# Day 49 | 1 newly infected | 584 total infected | 416 have recovered
#      day  new_infections  infected  recovered  immune  alive
# 0      0              12        32          0       0   1000
# 1      1              11        43          0       0   1000
# 2      2               8        51          0       0   1000
# 3      3              10        61          0       0   1000
# 4      4              15        76          0       0   1000
# ..   ...             ...       ...        ...     ...    ...
# 145   45               0       583        416     416    417
# 146   46               0       583        416     416    417
# 147   47               0       583        416     416    417
# 148   48               0       583        416     416    417
# 149   49               1       584        416     416    416
#
# [150 rows x 6 columns]

# %%
# pd.DataFrame(p_zero)

# %%
print(np.random.normal(movement,move_sdev)*(-1 + 2*np.random.binomial(1,0.5)))
